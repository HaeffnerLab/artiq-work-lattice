# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from data_analysis_tools_artiq import data_analysis_artiq
from scipy.optimize import curve_fit

# %% [markdown]
# ## Passive radial trap frequency stability
# ### 2019-10-31 9:52pm through 2019-11-01 1:03am

# %%
data_path = '/Users/Ryan/Dropbox/Ryan/School/Berkeley/Lab/data_analysis/lattice/data'
experiment_name = 'MotionalAnalysisSpectrum'
start_date = '2019-10-31'
start_time = '2152_00'
end_date = '2019-11-01'
end_time = '0103_00'

data = data_analysis_artiq(experiment_name, start_date, start_time, end_date, end_time, data_path)

data.plot_2d_map()
t,f = data.plot_stability()
# Out:
# average frequency: -5208.333333333333 kHz
# standard deviation: 2442.924874908036 kHz
# C:\Users\Ryan\.conda\envs\qutip\lib\site-packages\scipy\optimize\minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
